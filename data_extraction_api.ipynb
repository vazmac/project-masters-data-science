# %%
# Data Extraction
import base64
import requests as rq
import json
import pandas as pd

# %%
# Function to obtain personalised token

def get_oauth_token():
    
    api_key = 'api_key'   # API key provided by Idealista
    secret = 'secret'   # Secret code provided by Idealista

    message = api_key + ":" + secret   # get personalised message

    auth = "Basic " + base64.b64encode(message.encode("ascii")).decode("ascii")   # Encode the message

    headers_dic = {"Authorization" : auth,
                   "Content-Type" : "application/x-www-form-urlencoded;charset=UTF-8"}   # Define headers

    params_dic = {"grant_type" : "client_credentials",   # Define request params
                  "scope" : "read"}

    r = rq.post("https://api.idealista.com/oauth/token",   # Perform the request with the api url, headers and params
                      headers = headers_dic,
                      params = params_dic)

    token = json.loads(r.text)['access_token']   # Get bearer token from api response, as a json

    return token

# %%
# The next step will be to define the search URL. This will be achieved by defining the filter parameters of the search 
# and combining them into the resulting URL.

# %%
# These are the parameters used to filter the search.

base_url = 'https://api.idealista.com/3.5/'     # Base search url
country = 'pt'     # Search country (es, it, pt)                          
language = 'pt'     # Search language (es, it, pt, en, ca) 
max_items = '50'     # Max items per call, the maximum set by Idealista is 50
operation = 'rent'     # Kind of operation (sale, rent) 
property_type = 'homes'     # Type of property (homes, offices, premises, garages, bedrooms)
locale = 'pt'     # description in portuguese language 
center = '38.74856538317771,-9.159916501020044'     # Coordinates of the search center "Hospital de Santa Maria"
distance = '8000'     # Max distance from the center "8km" (in order to cover the area of Lisbon)
sort = 'desc'# How to sort the found items

# %%
# Function to obtain search url with filters

def define_search_url(page_number):
    url = f"{base_url}{country}/search?operation={operation}&maxItems={max_items}&locale={locale}&center={center}\
    &distance={distance}&propertyType={property_type}&sort={sort}&numPage={page_number}&language={language}"
    return url

# %%
# get url with filters
url = define_search_url("test") # test function with pagination as "test"

# %%
url
# Out:
# 'https://api.idealista.com/3.5/pt/search?operation=rent&maxItems=50&locale=pt&center=38.74856538317771,-9.159916501020044&distance=8000&propertyType=homes&sort=desc&numPage=test&language=pt'

# %%
# Create a function in order to do the search

# %%
def search_api(url):  
    '''
    This function will use the token and url created previously, and return the search results.
    '''
    token = get_oauth_token()   #  Get the bearer token

    headers = {'Content-Type': 'Content-Type: multipart/form-data;',   # Define the search headers (specified in idealista email) 
               'Authorization' : 'Bearer ' + token}

    content = rq.post(url, headers = headers)   # Return the content from the request

    result = json.loads(content.text)   # Transform the result as a json file

    return result

# %%
# Since it is necessary to give pagination to the search and this corresponds to the first search, 
# pagination will be set to 1.
first_search_url = define_search_url(1)

# %%
first_search_url
# Out:
# 'https://api.idealista.com/3.5/pt/search?operation=rent&maxItems=50&locale=pt&center=38.74856538317771,-9.159916501020044&distance=8000&propertyType=homes&sort=desc&numPage=1&language=pt'

# %%
# Proceed to do the search with the paginated url
results = search_api(first_search_url)

# %%
# show first page results
results
# Out:
# {'elementList': [{'propertyCode': '33240191',
#    'thumbnail': 'https://img3.idealista.pt/blur/WEB_LISTING/0/id.pro.pt.image.master/58/83/bd/236971517.jpg',
#    'externalReference': '59691',
#    'numPhotos': 50,
#    'price': 1000.0,
#    'propertyType': 'flat',
#    'operation': 'rent',
#    'size': 96.0,
#    'rooms': 4,
#    'bathrooms': 1,
#    'address': 'Rua Cidade de Moçâmedes s/n',
#    'province': 'Lisboa',
#    'municipality': 'Camarate - Unhos - Apelação',
#    'district': 'Camarate',
#    'country': 'pt',
#    'latitude': 38.7938568,
#    'longitude': -9.1428376,
#    'showAddress': True,
#    'url': 'https://www.idealista.pt/imovel/33240191/',
#    'distance': '5249',
#    'description': 'Apartamento T4 Arrendar Camarate. Este apartamento está localizado numa zona tranquila com 4 quartos, completamente mobilado e equipada. Com excelentes acessos a Lisboa e apenas a 5 min do aeroporto. Marque já a sua visita...',
#    'hasVideo': False,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': False,
#    'priceByArea': 10.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Camarate - Unhos - Apelação, Loures',
#     'title': 'Apartamento na Rua Cidade de Moçâmedes s/n'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False,
#    'hasStaging': False,
#    'topNewDevelopment': False,
#    'topPlus': False},
#   {'propertyCode': '33240181',
#    'thumbnail': 'https://img3.idealista.pt/blur/WEB_LISTING/0/id.pro.pt.image.master/dd/2c/d0/236970882.jpg',
#    'externalReference': 'W-02V128',
#    'numPhotos': 39,
#    'price': 1750.0,
#    'propertyType': 'flat',
#    'operation': 'rent',
#    'size': 127.0,
#    'rooms': 2,
#    'bathrooms': 2,
#    'address': 'Calçada do Combro',
#    'province': 'Lisboa',
#    'municipality': 'Misericórdia',
#    'district': 'Príncipe Real - São Bento',
#    'country': 'pt',
#    'latitude': 38.712796,
#    'longitude': -9.1486068,
#    'showAddress': False,
#    'url': 'https://www.idealista.pt/imovel/33240181/',
#    'distance': '4096',
#    'description': "2 apartamento de charme disponíveis na Baixa Chiado, Lisboa. Descubra o estilo de vida único que estes encantadores apartamentos têm para oferecer. Situados no coração da Baixa Chiado, um dos bairros mais charmosos de Lisboa, estes espaços acolhedores são perfeitos para quem procura uma experiência de vida extraordinária. Características em destaque: - Localização excecional: No cobiçado bairro da Baixa Chiado, perto de lojas, cultura e entretenimento. - Quartos acolhedores com roupeiros embutidos: Amplo espaço de arrumação para maior comodidade. - Casas de banho completa: Design contemporâneo para o seu conforto. - Cozinhas em open space totalmente equipada: Electrodomésticos modernos para as suas necessidades diárias. - Totalmente mobilados e equipados: Tudo o que precisa para começar uma nova vida em Lisboa. Detalhes adicionais: - Modernos e acolhedores: O equilíbrio perfeito entre estilo e conforto. - Pronto a habitar: Uma oportunidade única de chamar este sítio de casa. Vistas: Desfrute das vistas da cidade a partir dos seus apartamentos virado para a frente. Marque já a sua visita! Freguesia que nasceu da fusão das antigas freguesias Mercês, Santa Catarina, Encarnação e São Paulo. Do Bairro Alto e Príncipe Real ao Cais do Sodré, são incontáveis os pontos de interesse turístico: os ascensores da Glória e da Bica, o Mercado da Ribeira, os Miradouros de São Pedro de Alcântara e de Santa Catarina e os próprios bares, restaurantes e vida noturna do Bairro Alto e Cais do Sodré. Príncipe Real, zona muito central, inserida num dos bairros históricos de Lisboa, é também uma zona privilegiada do ponto de vista de espaços públicos, ficando muito próximo do Jardim das Flores e do Jardim do Príncipe Real, equipados com jardim infantil e esplanadas, teatros e universidades. Bairro Alto é um dos bairros mais velhos e surpreendentes de Lisboa (mais de 500 anos), com ruas estreitas e pavimentadas, casas seculares e pequenas lojas tradicionais. Dispõe de vários bares, restaurantes e 'casas de fado' e uma atmosfera única. Um bairro 'trendy' onde as casas seculares se fundem com o comércio tradicional e os espaços de lazer, num misto de colorido e formas. Santa Catarina é, assim como outros tantos, um bairro que está totalmente construído sobre uma colina. Quando se fala em S.",
#    'hasVideo': False,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': True,
#    'priceByArea': 14.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Misericórdia, Lisboa',
#     'title': 'Apartamento em Calçada do Combro'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False,
#    'hasStaging': False,
#    'topNewDevelopment': False,
#    'topPlus': False},
#   {'propertyCode': '32620556',
#    'thumbnail': 'https://img3.idealista.pt/blur/WEB_LISTING/0/id.pro.pt.image.master/70/27/ba/213627794.jpg',
#    'externalReference': 'EX/002/2023',
#    'numPhotos': 10,
#    'floor': '1',
#    'price': 1250.0,
#    'propertyType': 'flat',
#    'operation': 'rent',
#    'size': 60.0,
#    'rooms': 1,
#    'bathrooms': 1,
#    'address': 'Rua da bela vista á graça',
#    'province': 'Lisboa',
#    'municipality': 'São Vicente',
#    'district': 'Graça',
#    'country': 'pt',
#    'latitude': 38.7197856,
#    'longitude': -9.1276389,
#    'showAddress': False,
#    'url': 'https://www.idealista.pt/imovel/32620556/',
#    'distance': '4251',
#    'description': 'Apartamento T1 Novo, cozinha equipada com placa vitroceramica, forno, maquina de lavar roupa, frigorifico, caldeira não tem gás, totalmente elétrico, totalmente mobilado A/C. Entrada em Dezembro de 2023.',
#    'hasVideo': False,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': False,
#    'priceByArea': 21.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'São Vicente, Lisboa',
#     'title': 'Apartamento na Rua da bela vista á graça'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False,
#    'hasStaging': False,
#    'highlight': {'groupDescription': 'Destaque'},
#    'topNewDevelopment': False,
#    'topPlus': False},
#   {'propertyCode': '33200256',
#    'thumbnail': 'https://img3.idealista.pt/blur/WEB_LISTING/0/id.pro.pt.image.master/ca/ac/a1/235439880.jpg',
#    'externalReference': 'olivais/001/2024',
#    'numPhotos': 17,
#    'floor': '3',
#    'price': 1500.0,
#    'propertyType': 'flat',
#    'operation': 'rent',
#    'size': 85.0,
#    'rooms': 1,
#    'bathrooms': 1,
#    'address': 'Av. Berlim',
#    'province': 'Lisboa',
#    'municipality': 'Olivais',
#    'country': 'pt',
#    'latitude': 38.7674934,
#    'longitude': -9.1159796,
#    'showAddress': False,
#    'url': 'https://www.idealista.pt/imovel/33200256/',
#    'distance': '4352',
#    'description': 'Excelente oportunidade de arrendar um belo apartamento T1 no 3º andar, com varanda e uma vista maravilhosa! Este apartamento está totalmente mobilado e equipado com uma cozinha moderna e funcional. O prédio é recente e a localização é perfeita, a apenas 5 minutos a pé da Expo. Além disso, está perto da Gare do Oriente e do Centro Comercial Vasco da Gama, onde pode encontrar tudo o que precisa. Para os amantes de desporto, há um ginásio próximo ao apartamento. A orientação solar é sul, tornando-o muito luminoso e acolhedor. O apartamento também inclui um lugar de garagem. Aproveite os ótimos passeios a pé junto ao rio e desfrute da beleza da cidade. Por favor, note que este apartamento está localizado no 3º andar e tem elevador. Não perca esta oportunidade única!',
#    'hasVideo': False,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': True,
#    'parkingSpace': {'hasParkingSpace': True,
#     'isParkingSpaceIncludedInPrice': True},
#    'priceByArea': 18.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Olivais, Lisboa',
#     'title': 'Apartamento em Av. Berlim'},
#    'hasPlan': True,
#    'has3DTour': False,
#    'has360': True,
#    'hasStaging': False,
#    'highlight': {'groupDescription': 'Destaque'},
#    'topNewDevelopment': False,
#    'topPlus': False},
#   {'propertyCode': '33240084',
#    'thumbnail': 'https://img3.idealista.pt/blur/WEB_LISTING/0/id.pro.pt.image.master/bc/08/92/236968312.jpg',
#    'externalReference': 'APA_1952',
#    'numPhotos': 16,
#    'floor': '3',
#    'price': 1500.0,
#    'propertyType': 'flat',
#    'operation': 'rent',
#    'size': 72.45,
#    'rooms': 2,
#    'bathrooms': 1,
#    'address': 'Gare do Oriente - Zona Sul',
#    'province': 'Lisboa',
#    'municipality': 'Parque das Nações',
#    'district': 'Gare do Oriente - Zona Sul',
#    'country': 'pt',
#    'latitude': 38.7720269,
#    'longitude': -9.0999203,
#    'showAddress': False,
#    'url': 'https://www.idealista.pt/imovel/33240084/',
#    'distance': '5819',
#    'description': 'Apartamento T2 para arrendamento, pronto a estrear, no Parque das Nações Apartamento T2 com 63m2, não mobilado, com elevador, pronto a estrear. Isento de licença de utilização (edificado em data anterior a 1951). Seja o primeiro a viver neste novo apartamento, inserido numa estrutura histórica, com elevador, no coração da requintada zona da Gare do Oriente, no Parque das Nações. A sua localização privilegiada junto dos principais acessos, seja a estação ferroviária, a estação de metro ou até mesmo a Avenida Infante D. Henrique ou a Ponte Vasco da Gama, complementada por uma varanda comum à sala e a um dos quartos, que proporciona uma entrada direta de luz natural. Nas traseiras da cozinha encontra-se um parque de estacionamento público, onde poderá sem dificuldade estacionar a sua viatura privada. O apartamento dispõe de uma sala espaçosa e dois quartos, com roupeiros, bem separado da zona social do apartamento. A um curto passeio, encontra-se o Casino de Lisboa, o Oceanário de Lisboa, a Feira Internacional de Lisboa e o Centro Comercial do Vasco da Gama. A estação ferroviária e de metro da Gare do Oriente fica a apenas 5 minutos a pé, enquanto o acesso à ponte Vasco da Gama fica a 5 minutos de carro. Explore os convidativos cafés e restaurantes do bairro em segundos, mergulhando num ambiente tranquilo.  Para informações adicionais sobre este imóvel, contacte o Grupo Homing! A nossa equipa dedicada está preparada para o orientar ao longo de todo o processo e responder a quaisquer questões relacionadas com a compra, venda ou arrendamento. Marque a sua visita hoje mesmo! ENG Brand new 2-bedroom apartment for rent in Parque das Nações 2 bedroom apartment with 63m2, unfurnished, with elevator, ready to move into. Exempt from use license (built before 1951). Be the first to live in this new apartment, set in a historic structure, with elevator, in the heart of the exquisite Gare do Oriente area, in Parque das Nações. Its privileged location close to the main access points, be it the train station, the metro station or even Avenida Infante D. Henrique or the Vasco da Gama Bridge, is complemented by a balcony common to the living room and one of the bedrooms, which provides a direct entry to natural light. To the rear of the kitchen is a public parking.',
#    'hasVideo': False,
#    'status': 'good',
#    'newDevelopment': False,
#    'priceByArea': 21.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Parque das Nações, Lisboa',
#     'title': 'Apartamento'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False,
#    'hasStaging': False,
#    'topNewDevelopment': False,
#    'topPlus': False},
#   {'propertyCode': '33240069',
#    'thumbnail': 'https://img3.idealista.pt/blur/WEB_LISTING/0/id.pro.pt.image.master/5d/b6/04/236967779.jpg',
#    'externalReference': 'APA_338_B',
#    'numPhotos': 13,
#    'floor': '1',
#    'price': 1500.0,
#    'propertyType': 'flat',
#    'operation': 'rent',
#    'size': 475.0,
#    'rooms': 1,
#    'bathrooms': 1,
#    'address': 'Saldanha - Picoas',
#    'province': 'Lisboa',
#    'municipality': 'Arroios',
#    'district': 'São Jorge de Arroios',
#    'country': 'pt',
#    'neighborhood': 'Saldanha - Picoas',
#    'latitude': 38.7344758,
#    'longitude': -9.141786,
#    'showAddress': False,
#    'url': 'https://www.idealista.pt/imovel/33240069/',
#    'distance': '2219',
#    'description': 'Apartamento T1 em avenida central e a poucos passos da Praça do Saldanha.  Com 47 m2, o apartamento conta uma sala de estar e jantar em open space com a cozinha. A cozinha encontra-se equipada com exaustor, placa vitrocerâmica, frigorífico, máquina de lavar loiça e máquina de lavar roupa. Dispõe ainda de um quarto com roupeiro embutido e uma casa de banho completa. Tanto o quarto como a sala dão acesso ao terraço. Conta com vidro duplos para bom isolamento acústico e de aquecimento central. Há a possibilidade de arrendar com um lugar de estacionamento. Encontra-se inserido em edifício moderno, com dois elevadores, numa das principais avenidas do bairro. A sua localização central oferece uma ampla oferta de serviços, restaurantes, comércio, excelentes acessos rodoviários e boa rede de transportes. Licença de utilização nº 1323UT/2006.',
#    'hasVideo': False,
#    'status': 'renew',
#    'newDevelopment': False,
#    'hasLift': True,
#    'priceByArea': 3.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Saldanha - Picoas, Lisboa',
#     'title': 'Apartamento'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False,
#    'hasStaging': False,
#    'topNewDevelopment': False,
#    'topPlus': False},
#   {'propertyCode': '33240073',
#    'thumbnail': 'https://img3.idealista.pt/blur/WEB_LISTING/0/id.pro.pt.image.master/aa/2b/c4/236967562.jpg',
#    'externalReference': '5347',
#    'numPhotos': 46,
#    'floor': '8',
#    'price': 3750.0,
#    'propertyType': 'flat',
#    'operation': 'rent',
#    'size': 210.0,
#    'rooms': 4,
#    'bathrooms': 3,
#    'address': 'Rua Gregório Lopes',
#    'province': 'Lisboa',
#    'municipality': 'Belém',
#    'district': 'Restelo',
#    'country': 'pt',
#    'latitude': 38.7100272,
#    'longitude': -9.211855,
#    'showAddress': False,
#    'url': 'https://www.idealista.pt/imovel/33240073/',
#    'distance': '6217',
#    'description': 'Experimente o epítome da vida moderna neste apartamento novo, totalmente renovado e não mobilado, que possui uma luminosidade e amplitude inigualáveis, acompanhadas de vistas deslumbrantes, especialmente para o esplêndido rio. A propriedade recebe-o com a conveniência de duas portas de entrada separadas, garantindo flexibilidade e acessibilidade aos residentes. Composto por 3+1 quartos, armários embutidos, incluindo um em suite, o layout foi concebido para oferecer um equilíbrio perfeito entre conforto e privacidade. Mantenha o controlo do seu clima com um sistema de ar condicionado totalmente equipado, gerido remotamente através de Wi-Fi, tanto nos quartos como na sala de jantar/estar. O apartamento está também preparado para a pré-instalação de Wi-Fi, com tomadas RJ45 em todo o apartamento para uma conetividade perfeita, cobrindo 100% do espaço. Aumente a sua privacidade e segurança com estores eléctricos, uma comodidade moderna que complementa o design cuidadoso desta residência. As casas de banho estão bem equipadas com um chuveiro de WC, um toalheiro elétrico aquecido, um exaustor silencioso e um espelho aquecido, proporcionando uma experiência luxuosa e confortável. A cozinha totalmente equipada é um paraíso culinário, com uma máquina de lavar louça, máquina de lavar e secar roupa, micro-ondas, placa de fogão e um impressionante frigorífico/congelador side-by-side. Além disso, a propriedade incorpora uma linha de retorno de água quente com uma bomba de recirculação programável e uma válvula misturadora termostática, garantindo água quente a pedido. Com uma generosa área bruta de 210 m² e 165 m² de espaço útil, incluindo 3 casas de banho (2 totalmente equipadas e 1 lavabo), este apartamento T4 oferece um amplo espaço para uma vida confortável. Relaxe e desfrute do ar livre no seu terraço privado. Esta propriedade também inclui valiosos complementos, como um lugar de estacionamento e uma arrecadação. Beneficie da luz natural ideal e da exposição solar com uma orientação sul e leste no 8º andar, facilmente acessível com a conveniência de um elevador.',
#    'hasVideo': True,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': True,
#    'parkingSpace': {'hasParkingSpace': True,
#     'isParkingSpaceIncludedInPrice': True},
#    'priceByArea': 18.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Belém, Lisboa',
#     'title': 'Apartamento na Rua Gregório Lopes'},
#    'hasPlan': True,
#    'has3DTour': False,
#    'has360': False,
#    'hasStaging': False,
#    'labels': [{'name': 'luxuryType', 'text': 'De luxo'}],
#    'topNewDevelopment': False,
#    'topPlus': False},
#   {'propertyCode': '31901010',
#    'thumbnail': 'https://img3.idealista.pt/blur/WEB_LISTING/0/id.pro.pt.image.master/f1/cd/81/236970538.jpg',
#    'externalReference': 'PF27535',
#    'numPhotos': 38,
#    'floor': '3',
#    'price': 2000.0,
#    'propertyType': 'duplex',
#    'operation': 'rent',
#    'size': 70.0,
#    'rooms': 2,
#    'bathrooms': 2,
#    'address': 'Campo Pequeno',
#    'province': 'Lisboa',
#    'municipality': 'Avenidas Novas',
#    'district': 'Campo Pequeno',
#    'country': 'pt',
#    'latitude': 38.7435989,
#    'longitude': -9.1452173,
#    'showAddress': False,
#    'url': 'https://www.idealista.pt/imovel/31901010/',
#    'distance': '1389',
#    'description': "Apartamento T2 Duplex sem móveis localizado no Campo Pequeno: As áreas dividem-se por: - Sala de Estar - Quarto com zona de closet - Kitchenette equipada -Wc completo com base de duche Duplex - Suite com wc completo Imóvel equipado com ar condicionado, janelas com vidros duplos, localizado próximo ao centro comercial do Campo Pequeno, junto a uma vasta oferta de serviços e de comércio, farmácias, restaurantes, etc. Lisboa A capital Portuguesa é onde tudo acontece: desde os seus bairros históricos às novas ruas cheias de vida, Lisboa é a cidade que nunca para de surpreender. Pode passear por avenidas icónicas como a Liberdade ou comer os deliciosos pastéis de Belém, sem esquecer as opções culturais e inúmeros museus da cidade. Um oásis urbano que serve o amante da calçada portuguesa e o curioso pela modernidade. A Porta da Frente Christie's é uma empresa de mediação imobiliária que trabalha no mercado há mais de duas décadas, focando-se nos melhores imóveis e empreendimentos, quer para venda quer para arrendamento. A empresa foi selecionada pela prestigiada marca Christie's International Real Estate para representar Portugal, nas zonas de Lisboa, Cascais, Oeiras e Alentejo. A principal missão da Porta da Frente Christie's é privilegiar um serviço de excelência a todos os nossos clientes.",
#    'hasVideo': True,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': False,
#    'priceByArea': 29.0,
#    'detailedType': {'typology': 'flat', 'subTypology': 'duplex'},
#    'suggestedTexts': {'subtitle': 'Avenidas Novas, Lisboa', 'title': 'Duplex'},
#    'hasPlan': True,
#    'has3DTour': False,
#    'has360': False,
#    'hasStaging': False,
#    'topNewDevelopment': False,
#    'topPlus': False},
#   {'propertyCode': '32592478',
#    'thumbnail': 'https://img3.idealista.pt/blur/WEB_LISTING/0/id.pro.pt.image.master/10/b1/90/226681720.jpg',
#    'numPhotos': 9,
#    'floor': '3',
#    'price': 1500.0,
#    'propertyType': 'flat',
#    'operation': 'rent',
#    'size': 50.0,
#    'rooms': 1,
#    'bathrooms': 1,
#    'address': 'Praça da Alegria',
#    'province': 'Lisboa',
#    'municipality': 'Santo António',
#    'district': 'Praça da Alegria',
#    'country': 'pt',
#    'latitude': 38.716796,
#    'longitude': -9.1436618,
#    'showAddress': False,
#    'url': 'https://www.idealista.pt/imovel/32592478/',
#    'distance': '3803',
#    'description': "Welcome to our listing for a lovely T1 apartment for rent located in Conceição da Glória on Avenida da Liberdade. This apartment is perfect for those seeking a cozy and comfortable living space in a great location. The apartment features one bedroom and is located on the 3rd floor of the building. It boasts great natural light throughout, making the apartment feel bright and airy. Additionally, there is a nice balcony off the living area where you can enjoy your morning coffee or take in the city views. The bedroom is a comfortable size. The bathroom is modern and functional, featuring a shower and all necessary amenities. The location of this apartment is unbeatable. Situated on Avenida da Liberdade, you'll be within walking distance to a variety of restaurants, cafes, shops, and public transportation options. Overall, this T1 apartment is perfect for anyone looking for a comfortable and convenient place to call home. Don't miss out on this amazing opportunity - schedule a viewing today!",
#    'hasVideo': False,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': False,
#    'priceByArea': 30.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Santo António, Lisboa',
#     'title': 'Apartamento'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False,
#    'hasStaging': False,
#    'highlight': {'groupDescription': 'Destaque'},
#    'topNewDevelopment': False,
#    'topPlus': False},
#   {'propertyCode': '32788249',
#    'thumbnail': 'https://img3.idealista.pt/blur/WEB_LISTING/0/id.pro.pt.image.master/c3/5c/e7/220224308.jpg',
#    'externalReference': 'LADISPOLI',
#    'numPhotos': 26,
#    'floor': '2',
#    'price': 2050.0,
#    'propertyType': 'flat',
#    'operation': 'rent',
#    'size': 59.0,
#    'rooms': 1,
#    'bathrooms': 1,
#    'address': 'Rua do Patrocínio',
#    'province': 'Lisboa',
#    'municipality': 'Estrela',
#    'district': 'Lapa',
#    'country': 'pt',
#    'latitude': 38.7123518,
#    'longitude': -9.1626699,
#    'showAddress': False,
#    'url': 'https://www.idealista.pt/imovel/32788249/',
#    'distance': '4033',
#    'description': '*COMPLETAMENTE MOBILIADO* *RENDAS MENSAIS DE 1 A 11 MESES* Bem-vindo à Ladispoli, um charmoso apartamento com tema de praia localizado em Estrela. Esse bairro pitoresco abrange uma variedade de jardins e edifícios históricos, deixando muito a ser explorado. Com 59 metros quadrados, venha para casa neste espaço aconchegante e bem equipado, que oferece uma maravilhosa mistura de vibrações costeiras e confortos modernos para uma estadia agradável no coração da cidade. Ladispoli apresenta um quarto lindamente projetado com uma confortável cama queen-size, proporcionando um refúgio tranquilo e repousante para uma boa noite de sono. O tema de design de praia nesse quarto cria uma atmosfera tranquila e relaxante, permitindo que você se descontraia e relaxe após um dia de exploração da cidade. O apartamento vem completo com um banheiro elegante, equipado com todas as comodidades necessárias para tornar sua estadia confortável e conveniente.  O coração do apartamento é sua espaçosa sala de estar, cuidadosamente mobiliada para proporcionar conforto e funcionalidade. Uma área de estar aconchegante lhe dá as boas-vindas para relaxar e desfrutar de momentos de lazer, enquanto o sistema de entretenimento completo garante infinitas opções de entretenimento. Além disso, uma estação de trabalho dedicada na sala de estar oferece um local conveniente para colocar o trabalho em dia ou simplesmente planejar suas aventuras em Lisboa. A cozinha totalmente mobiliada é um deleite para os entusiastas da culinária, completa com eletrodomésticos modernos e todos os utensílios de cozinha necessários. A mesa de jantar adjacente o convida a saborear refeições caseiras ou a saborear as delícias da culinária local.  Saia da sala de estar para uma pequena varanda, onde você pode aproveitar o ar fresco e tomar seu café da manhã ou drinques à noite. Esse charmoso recanto ao ar livre é o local perfeito para absorver o ambiente da cidade e apreciar a vista da vizinhança. Para seu maior conforto, há unidades individuais de ar condicionado em cada quarto, garantindo que você possa ajustar a temperatura de acordo com sua preferência. Totalmente mobiliado, este apartamento vem com tudo o que você precisa, incluindo roupas de cama e de banho.  *Os preços estão sujeitos à duração da estadia e ao tempo de antecedência da reserva. *Os serviços de utilidade pública e as taxas para animais de estimação estão sujeitos a aplicação. Os clientes serão informados de quaisquer encargos adicionais no contrato final. * IMPORTANTE * A nossa prioridade é o conforto, segurança e bem-estar dos nossos hóspedes. Cumprimos rigorosamente todas as normas Covid-19 e protocolos de limpeza com níveis de limpeza melhorados. O apartamento é submetido a uma limpeza profunda completa entre estadias para satisfazer todos os requisitos sanitários.',
#    'hasVideo': True,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': False,
#    'priceByArea': 35.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Estrela, Lisboa',
#     'title': 'Apartamento na Rua do Patrocínio'},
#    'hasPlan': True,
#    'has3DTour': False,
#    'has360': True,
#    'hasStaging': False,
#    'highlight': {'groupDescription': 'Destaque'},
#    'topNewDevelopment': False,
#    'topPlus': False},
#   {'propertyCode': '32845919',
#    'thumbnail': 'https://img3.idealista.pt/blur/WEB_LISTING/0/id.pro.pt.image.master/2e/a9/a2/222943125.jpg',
#    'externalReference': 'ANNUNZIATA',
#    'numPhotos': 25,
#    'floor': '1',
#    'price': 1915.0,
#    'propertyType': 'flat',
#    'operation': 'rent',
#    'size': 57.0,
#    'rooms': 1,
#    'bathrooms': 1,
#    'address': 'Travessa Henrique Cardoso',
#    'province': 'Lisboa',
#    'municipality': 'Alvalade',
#    'district': 'Alvalade',
#    'country': 'pt',
#    'latitude': 38.7471805,
#    'longitude': -9.1419791,
#    'showAddress': False,
#    'url': 'https://www.idealista.pt/imovel/32845919/',
#    'distance': '1563',
#    'description': '*APARTAMENTO COM LUGAR DE GARAGEM* *COMPLETAMENTE MOBILADO* *ARRENDAMENTO MENSAIS DE 1 A 11 MESES* Bem-vindo ao Annunziata, um charmoso apartamento de 57 m² localizado no coração de Alvalade, em Lisboa. Prepare-se para experimentar uma fusão perfeita de conforto, estilo e design cativante com tema de praia.  O Annunziata possui um quarto confortável adornado com uma cama de casal, garantindo noites tranquilas e manhãs serenas. O design com tema de praia confere ao espaço uma atmosfera relaxante e acolhedora, que lembra as praias arenosas e as suaves ondas do mar. Para hóspedes adicionais ou para uma pausa aconchegante à tarde, há um sofá-cama na sala de estar. O banheiro tem um design elegante e funcional e apresenta uma banheira tipo spa, perfeita para mergulhar.  A sala de estar é uma área espaçosa e versátil onde você pode relaxar, jantar ou colocar o trabalho em dia. Um sistema de entretenimento está à sua disposição para o lazer, enquanto uma estação de trabalho dedicada oferece um espaço conveniente para a produtividade. A mesa de jantar é perfeita para compartilhar refeições e criar boas lembranças. A cozinha totalmente mobiliada tem todos os utensílios necessários para preparar uma refeição deliciosa.  Mantenha o clima interno do jeito que você gosta com unidades de ar condicionado individuais em cada quarto. O Annunziata foi cuidadosamente projetado para atender a todos os hóspedes, com acesso para pessoas com mobilidade limitada para garantir o conforto de todos. Com o seu espaço de estacionamento designado, o estresse de procurar estacionamento na cidade é eliminado. Totalmente mobiliado, este apartamento vem com tudo o que você precisa, incluindo roupa de cama e lençóis. *Os preços estão sujeitos à duração da estadia e ao tempo de antecedência da reserva. *Os serviços de utilidade pública e as taxas para animais de estimação estão sujeitos a aplicação. Os clientes serão informados de quaisquer encargos adicionais no contrato final. * IMPORTANTE * A nossa prioridade é o conforto, segurança e bem-estar dos nossos hóspedes. Cumprimos rigorosamente todas as normas Covid-19 e protocolos de limpeza com níveis de limpeza melhorados. O apartamento é submetido a uma limpeza profunda completa entre estadias para satisfazer todos os requisitos sanitários.',
#    'hasVideo': True,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': True,
#    'parkingSpace': {'hasParkingSpace': True,
#     'isParkingSpaceIncludedInPrice': True},
#    'priceByArea': 34.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Alvalade, Lisboa',
#     'title': 'Apartamento na Travessa Henrique Cardoso'},
#    'hasPlan': True,
#    'has3DTour': False,
#    'has360': True,
#    'hasStaging': False,
#    'highlight': {'groupDescription': 'Destaque'},
#    'topNewDevelopment': False,
#    'topPlus': False},
#   {'propertyCode': '32693460',
#    'thumbnail': 'https://img3.idealista.pt/blur/WEB_LISTING/0/id.pro.pt.image.master/e8/3e/83/217497275.jpg',
#    'externalReference': 'CIVITA',
#    'numPhotos': 27,
#    'floor': '1',
#    'price': 3110.0,
#    'propertyType': 'duplex',
#    'operation': 'rent',
#    'size': 203.0,
#    'rooms': 4,
#    'bathrooms': 2,
#    'address': 'Avenida dos Estados Unidos da América',
#    'province': 'Lisboa',
#    'municipality': 'Alvalade',
#    'district': 'Alvalade',
#    'country': 'pt',
#    'latitude': 38.7506999,
#    'longitude': -9.1429492,
#    'showAddress': False,
#    'url': 'https://www.idealista.pt/imovel/32693460/',
#    'distance': '1490',
#    'description': '*APARTAMENTO COM TERRAÇO E VERANDA* *COMPLETAMENTE MOBILIADO* Bem-vindo ao Civita, um requintado apartamento com tema de praia situado no charmoso bairro de Alvalade. As grandes avenidas e os espaços verdes desse bairro fazem dele um paraíso residencial. Seja para um passeio no parque ou para fazer compras, volte para casa no Civita e experimente um refúgio de relaxamento e estilo durante sua estadia. Com impressionantes 203 metros quadrados, o Civita tem três quartos duplos, cada um com uma cama queen size. Dois dos quartos possuem banheiros privativos, o que permite maior privacidade e conveniência. Há também um quarto de solteiro com uma estação de trabalho dedicada, proporcionando um espaço confortável para trabalhar ou estudar durante sua estadia. Cada um oferece acesso à varanda, onde você pode sair e aproveitar o ar fresco. O Civita está bem equipado com um total de 2,5 banheiros, com acessórios e comodidades modernas.  O coração do apartamento é a convidativa sala de estar, cuidadosamente projetada para proporcionar conforto e entretenimento. A luz do sol que entra pelo lado de fora se mistura perfeitamente com a madeira clara e os tons de areia do espaço. Relaxe nos assentos macios enquanto desfruta do sistema de entretenimento completo, perfeito para noites aconchegantes de cinema ou para assistir aos seus programas favoritos. A mesa de jantar na sala de estar oferece um espaço elegante para desfrutar de refeições ou reunir-se com pessoas queridas. Com acesso à varanda a partir da sala de estar, você pode sair e saborear o ambiente agradável enquanto aprecia a vista ao redor. O Civita possui uma cozinha totalmente mobiliada, completa com aparelhos modernos e amplo espaço no balcão. Quer você seja um entusiasta da culinária ou prefira refeições simples, encontrará tudo o que precisa para preparar pratos deliciosos durante a sua estadia. Para maior conforto, o Civita é equipado com aquecimento por radiador, garantindo uma atmosfera aconchegante e agradável durante sua estadia. Com um porteiro à disposição, você pode se sentir seguro e bem assistido durante sua estadia no Civita.Totalmente mobiliado, este apartamento vem com tudo o que você precisa, incluindo roupas de cama e de banho. *Os preços estão sujeitos à duração da estadia e ao tempo de antecedência da reserva. *Os serviços de utilidade pública e as taxas para animais de estimação estão sujeitos a aplicação. Os clientes serão informados de quaisquer encargos adicionais no contrato final. * IMPORTANTE * A nossa prioridade é o conforto, segurança e bem-estar dos nossos hóspedes. Cumprimos rigorosamente todas as normas Covid-19 e protocolos de limpeza com níveis de limpeza melhorados. O apartamento é submetido a uma limpeza profunda completa entre estadias para satisfazer todos os requisitos sanitários.',
#    'hasVideo': True,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': True,
#    'priceByArea': 15.0,
#    'detailedType': {'typology': 'flat', 'subTypology': 'duplex'},
#    'suggestedTexts': {'subtitle': 'Alvalade, Lisboa',
#     'title': 'Duplex na Avenida dos Estados Unidos da América'},
#    'hasPlan': True,
#    'has3DTour': False,
#    'has360': True,
#    'hasStaging': False,
#    'labels': [{'name': 'luxuryType', 'text': 'De luxo'}],
#    'highlight': {'groupDescription': 'Destaque'},
#    'topNewDevelopment': False,
#    'topPlus': False},
#   {'propertyCode': '32943551',
#    'thumbnail': 'https://img3.idealista.pt/blur/WEB_LISTING/0/id.pro.pt.image.master/49/df/b6/228484218.jpg',
#    'externalReference': 'AURUNCA',
#    'numPhotos': 24,
#    'floor': '1',
#    'price': 3060.0,
#    'propertyType': 'flat',
#    'operation': 'rent',
#    'size': 125.0,
#    'rooms': 3,
#    'bathrooms': 3,
#    'address': 'Avenida Elias Garcia',
#    'province': 'Lisboa',
#    'municipality': 'Avenidas Novas',
#    'district': 'Campo Pequeno',
#    'country': 'pt',
#    'latitude': 38.7398925,
#    'longitude': -9.1484502,
#    'showAddress': False,
#    'url': 'https://www.idealista.pt/imovel/32943551/',
#    'distance': '1385',
#    'description': '*COMPLETAMENTE MOBILIADO* *RENDAS MENSAIS DE 1 A 11 MESES* Experimente o epítome do conforto e do charme costeiro em Aurunca, um deslumbrante apartamento de 125 metros quadrados situado no vibrante bairro das Avenidas Novas. Este bairro exuberante oferece as vistas mais deslumbrantes de Lisboa, ao mesmo tempo que está bem ligado. Depois de um longo dia, volte para casa no Aurunca para uma indulgência absoluta.  Descubra o conforto luxuoso de três quartos elegantemente decorados, cada um com uma cama queen-size. Um quarto possui uma casa de banho privativa e um espaçoso closet, garantindo comodidade e estilo, enquanto outro quarto oferece uma casa de banho privativa e uma estação de trabalho dedicada, perfeita para trabalho ou actividades criativas. A casa de banho independente tem um design elegante e funcional. Descontraia-se na sala de estar e na cozinha em plano aberto, adornadas com um cativante tema de design de praia, com destaque para os tons neutros da costa e requintados toques de madeira flutuante, invocando o ambiente tranquilo de uma fuga serena à beira-mar. A sala de estar está equipada com um sistema de entretenimento e uma elegante mesa de jantar, criando um espaço ideal para relaxamento e reuniões sociais. A cozinha totalmente mobilada, completa com uma conveniente bancada para sentar, convida-o a libertar a sua criatividade culinária e a preparar deliciosas refeições. Mantenha-se fresco e confortável com o ar condicionado split em todas as divisões, garantindo um ambiente agradável durante toda a sua estadia, independentemente da temperatura exterior. Totalmente mobilado, este apartamento tem tudo o que precisa, incluindo roupa de cama e toalhas. *Os preços estão sujeitos à duração da estadia e ao tempo de antecedência da reserva. *Os serviços de utilidade pública e as taxas para animais de estimação estão sujeitos a aplicação. Os clientes serão informados de quaisquer encargos adicionais no contrato final. * IMPORTANTE * A nossa prioridade é o conforto, segurança e bem-estar dos nossos hóspedes. Cumprimos rigorosamente todas as normas Covid-19 e protocolos de limpeza com níveis de limpeza melhorados. O apartamento é submetido a uma limpeza profunda completa entre estadias para satisfazer todos os requisitos sanitários.',
#    'hasVideo': True,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': True,
#    'priceByArea': 24.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Avenidas Novas, Lisboa',
#     'title': 'Apartamento na Avenida Elias Garcia'},
#    'hasPlan': True,
#    'has3DTour': False,
#    'has360': True,
#    'hasStaging': False,
#    'labels': [{'name': 'luxuryType', 'text': 'De luxo'}],
#    'highlight': {'groupDescription': 'Destaque'},
#    'topNewDevelopment': False,
#    'topPlus': False},
#   {'propertyCode': '32249220',
#    'thumbnail': 'https://img3.idealista.pt/blur/WEB_LISTING/0/id.pro.pt.image.master/58/5a/d5/198898205.jpg',
#    'externalReference': 'BADAJOZ',
#    'numPhotos': 26,
#    'floor': '1',
#    'price': 3520.0,
#    'propertyType': 'flat',
#    'operation': 'rent',
#    'size': 132.0,
#    'rooms': 3,
#    'bathrooms': 3,
#    'address': 'Rua Almirante Barroso',
#    'province': 'Lisboa',
#    'municipality': 'Arroios',
#    'district': 'São Jorge de Arroios',
#    'country': 'pt',
#    'neighborhood': 'Saldanha - Picoas',
#    'latitude': 38.7306556,
#    'longitude': -9.1422614,
#    'showAddress': False,
#    'url': 'https://www.idealista.pt/imovel/32249220/',
#    'distance': '2511',
#    'description': '*APARTAMENTO COM TERRAÇO* *COMPLETAMENTE MOBILADO*  *A RENDA MENSAL DE 1 A 11 MESES*  Esta propriedade única de 132 metros quadrados apresenta a beleza da arquitectura lisboeta combinada com um design único de prado. Badajoz está localizado no bairro de Arroios. Considerado como o Montmartre de Lisboa, o bairro de Arroios promete uma estética artística, espectáculos locais e comida de fusão inigualável. Depois de um passeio pelas ruas de Lisboa, não há nada melhor do que relaxar em casa.  O Badajoz oferece conforto e estilo nos seus 3 quartos e 3 casas de banho. Dos 3 quartos, os hóspedes encontrarão 3 camas queen-size. O primeiro quarto é acolhedor, com uma cabeceira rústica. Ao lado, os hóspedes encontrarão a elegante casa de banho independente. Os outros dois quartos têm casas de banho privativas, com chuveiros walk-in e uma porta que dá para o grande terraço. Mesmo à porta dos quartos, há cadeiras onde os hóspedes são bem-vindos para descansar à sombra, ou podem descer as escadas para a área relvada para se deitarem ao sol português.  A sala de estar e a cozinha em plano aberto encontram-se na parte da frente do edifício, com vista para a rua. A sala de estar tem um sistema de entretenimento completo e uma estação de trabalho dedicada, ostentando tanto estilo como função. Atrás do sofá encontra-se uma grande mesa rústica, com capacidade para seis pessoas. A cozinha é recente, totalmente equipada e decorada com estilo. Os toques de madeira, as ervas secas, as plantas e as telas penduradas dão um toque de pradaria ao espaço. Totalmente mobilada, esta casa vem com tudo o que precisa, incluindo roupa de cama e roupa de cama. *Por favor, note que este apartamento não permite animais de estimação. *Os preços estão sujeitos à duração da estadia e ao tempo de antecedência da reserva. *Os serviços de utilidade pública estão sujeitos a aplicação. Os clientes serão informados de quaisquer encargos adicionais no contrato final. * IMPORTANTE * A nossa prioridade é o conforto, segurança e bem-estar dos nossos hóspedes. Cumprimos rigorosamente todas as normas Covid-19 e protocolos de limpeza com níveis de limpeza melhorados. O apartamento é submetido a uma limpeza profunda completa entre estadias para satisfazer todos os requisitos sanitários.',
#    'hasVideo': True,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': True,
#    'priceByArea': 27.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Saldanha - Picoas, Lisboa',
#     'title': 'Apartamento na Rua Almirante Barroso'},
#    'hasPlan': True,
#    'has3DTour': False,
#    'has360': True,
#    'hasStaging': False,
#    'labels': [{'name': 'luxuryType', 'text': 'De luxo'}],
#    'highlight': {'groupDescription': 'Destaque'},
#    'topNewDevelopment': False,
#    'topPlus': False},
#   {'propertyCode': '33161299',
#    'thumbnail': 'https://img3.idealista.pt/blur/WEB_LISTING/0/id.pro.pt.image.master/7b/57/7e/234887912.jpg',
#    'externalReference': 'ALMEIRIM',
#    'numPhotos': 26,
#    'floor': '2',
#    'price': 3250.0,
#    'propertyType': 'flat',
#    'operation': 'rent',
#    'size': 115.0,
#    'rooms': 2,
#    'bathrooms': 2,
#    'address': 'Rua Capitão Ramires',
#    'province': 'Lisboa',
#    'municipality': 'Areeiro',
#    'district': 'Av. de Roma - Campo Pequeno',
#    'country': 'pt',
#    'latitude': 38.7439888,
#    'longitude': -9.1419398,
#    'showAddress': False,
#    'url': 'https://www.idealista.pt/imovel/33161299/',
#    'distance': '1639',
#    'description': '*APARTAMENTO COM ESTACIONAMENTO E PISCINA* *COMPLETAMENTE MOBILIADO* *RENDAS MENSAIS DE 1 A 11 MESES* Espetacular apartamento na Rua Capitão Ramires, com 2 quartos, varanda e 2 casas de banho. A cozinha está equipada com electrodomésticos e utensílios de cozinha topo de gama. As camas estão equipadas com roupa de cama macia, ideal para uma boa noite de descanso. O apartamento tem 2 casas de banho equipadas com um chuveiro completo e toalhas. O edifício oferece uma piscina partilhada e um terraço partilhado, e providencia um lugar de estacionamento designado para os hóspedes. Além disso, o apartamento está equipado com acesso Wi-Fi de alta velocidade e SmartTV. O apartamento tem uma máquina de lavar roupa, máquina de lavar louça e forno para o seu máximo conforto. *Para um máximo conforto, este apartamento está equipado com um sistema de ar condicionado por condutas. *Os preços estão sujeitos à duração da estadia e ao tempo de antecedência da reserva. *Os serviços de utilidade pública e as taxas para animais de estimação estão sujeitos a aplicação. Os clientes serão informados de quaisquer encargos adicionais no contrato final.',
#    'hasVideo': True,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': True,
#    'parkingSpace': {'hasParkingSpace': True,
#     'isParkingSpaceIncludedInPrice': True},
#    'priceByArea': 28.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Areeiro, Lisboa',
#     'title': 'Apartamento na Rua Capitão Ramires'},
#    'hasPlan': True,
#    'has3DTour': False,
#    'has360': True,
#    'hasStaging': False,
#    'labels': [{'name': 'luxuryType', 'text': 'De luxo'}],
#    'highlight': {'groupDescription': 'Destaque'},
#    'topNewDevelopment': False,
#    'topPlus': False},
#   {'propertyCode': '33220289',
#    'thumbnail': 'https://img3.idealista.pt/blur/WEB_LISTING/0/id.pro.pt.image.master/c9/a0/f4/236771369.jpg',
#    'externalReference': 'CACELA',
#    'numPhotos': 24,
#    'floor': '4',
#    'price': 1915.0,
#    'propertyType': 'flat',
#    'operation': 'rent',
#    'size': 61.0,
#    'rooms': 1,
#    'bathrooms': 1,
#    'address': 'Avenida Berlim, 19',
#    'province': 'Lisboa',
#    'municipality': 'Olivais',
#    'country': 'pt',
#    'latitude': 38.7676694,
#    'longitude': -9.1062052,
#    'showAddress': True,
#    'url': 'https://www.idealista.pt/imovel/33220289/',
#    'distance': '5118',
#    'description': '*APARTAMENTO COM ESTACIONAMENTO* *COMPLETAMENTE MOBILIADO* *RENDAS MENSAIS DE 1 A 11 MESES* Espetacular apartamento na Avenida de Berlim, com 1 quarto e 1 casa de banho. A cozinha está equipada com electrodomésticos e utensílios de cozinha topo de gama. As camas estão equipadas com roupa de cama macia, ideal para uma boa noite de descanso. O apartamento tem 1 casa de banho equipada com uma banheira completa e toalhas. Além disso, o apartamento está equipado com WiFi de alta velocidade e SmartTV. O apartamento tem uma máquina de lavar roupa e uma máquina de lavar louça para o seu máximo conforto. *Para maior conforto, este apartamento está equipado com ar condicionado no quarto e na sala de estar. *Os preços estão sujeitos à duração da estadia e ao tempo de antecedência da reserva. *Os serviços de utilidade pública e as taxas para animais de estimação estão sujeitos a aplicação. Os clientes serão informados de quaisquer encargos adicionais no contrato final.',
#    'hasVideo': True,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': True,
#    'parkingSpace': {'hasParkingSpace': True,
#     'isParkingSpaceIncludedInPrice': True},
#    'priceByArea': 31.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Olivais, Lisboa',
#     'title': 'Apartamento na Avenida Berlim, 19'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': True,
#    'hasStaging': False,
#    'highlight': {'groupDescription': 'Destaque'},
#    'topNewDevelopment': False,
#    'topPlus': False},
#   {'propertyCode': '33128321',
#    'thumbnail': 'https://img3.idealista.pt/blur/WEB_LISTING/0/id.pro.pt.image.master/26/69/9a/235227581.jpg',
#    'externalReference': 'ALVARES',
#    'numPhotos': 26,
#    'floor': 'bj',
#    'price': 2020.0,
#    'propertyType': 'flat',
#    'operation': 'rent',
#    'size': 100.0,
#    'rooms': 1,
#    'bathrooms': 1,
#    'address': 'Rua Ilha Terceira',
#    'province': 'Lisboa',
#    'municipality': 'Arroios',
#    'district': 'São Jorge de Arroios',
#    'country': 'pt',
#    'neighborhood': 'Estefânia',
#    'latitude': 38.7336759,
#    'longitude': -9.1376733,
#    'showAddress': False,
#    'url': 'https://www.idealista.pt/imovel/33128321/',
#    'distance': '2542',
#    'description': '*APARTAMENTO COM TERRAÇO* *COMPLETAMENTE MOBILIADO* *RENDAS MENSAIS DE 1 A 11 MESES* Espetacular apartamento na Rua Ilha Terceira, com 1 quarto e 1 casa de banho. A cozinha está equipada com electrodomésticos e utensílios de cozinha topo de gama. A cama está equipada com roupa de cama macia, ideal para uma boa noite de descanso. O apartamento tem 1 casa de banho equipada com duche completo e toalhas. O apartamento tem um terraço privado de 62m2. Para além disso, o apartamento está equipado com WiFi de alta velocidade e SmartTV. O apartamento tem uma máquina de lavar roupa, máquina de lavar louça e ar condicionado para o seu máximo conforto. *Os preços estão sujeitos à duração da estadia e ao tempo de antecedência da reserva. *Os serviços de utilidade pública e as taxas para animais de estimação estão sujeitos a aplicação. Os clientes serão informados de quaisquer encargos adicionais no contrato final.',
#    'hasVideo': True,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': False,
#    'priceByArea': 20.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Estefânia, Lisboa',
#     'title': 'Apartamento na Rua Ilha Terceira'},
#    'hasPlan': True,
#    'has3DTour': False,
#    'has360': True,
#    'hasStaging': False,
#    'highlight': {'groupDescription': 'Destaque'},
#    'topNewDevelopment': False,
#    'topPlus': False},
#   {'propertyCode': '33231492',
#    'thumbnail': 'https://img3.idealista.pt/blur/WEB_LISTING/0/id.pro.pt.image.master/97/7d/8d/236863036.jpg',
#    'externalReference': 'GALE',
#    'numPhotos': 26,
#    'floor': 'bj',
#    'price': 2350.0,
#    'propertyType': 'flat',
#    'operation': 'rent',
#    'size': 59.0,
#    'rooms': 1,
#    'bathrooms': 1,
#    'address': 'Rua Capitão Ramires',
#    'province': 'Lisboa',
#    'municipality': 'Areeiro',
#    'district': 'Av. de Roma - Campo Pequeno',
#    'country': 'pt',
#    'latitude': 38.7432112,
#    'longitude': -9.1423312,
#    'showAddress': False,
#    'url': 'https://www.idealista.pt/imovel/33231492/',
#    'distance': '1637',
# ...
#    'hasVideo': False,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': True,
#    'parkingSpace': {'hasParkingSpace': True,
#     'isParkingSpaceIncludedInPrice': False,
#     'parkingSpacePrice': 100.0},
#    'priceByArea': 43.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Estefânia, Lisboa',
#     'title': 'Apartamento na Avenida Duque de Loulé'},
#    'hasPlan': True,
#    'has3DTour': False,
#    'has360': False,
#    'hasStaging': False,
#    'highlight': {'groupDescription': 'Destaque'},
#    'topNewDevelopment': False,
#    'topPlus': False},
#   {'propertyCode': '33083487',
#    'thumbnail': 'https://img3.idealista.pt/blur/WEB_LISTING/0/id.pro.pt.image.master/fc/99/4a/231214141.jpg',
#    'externalReference': 'LIS-199',
#    'numPhotos': 26,
#    'floor': '4',
#    'price': 3050.0,
#    'propertyType': 'flat',
#    'operation': 'rent',
#    'size': 96.0,
#    'rooms': 2,
#    'bathrooms': 2,
#    'address': 'Rua Duque de Palmela',
#    'province': 'Lisboa',
#    'municipality': 'Santo António',
#    'district': 'Av. da Liberdade - Marquês de Pombal',
#    'country': 'pt',
#    'latitude': 38.7228719,
#    'longitude': -9.1506111,
#    'showAddress': False,
#    'url': 'https://www.idealista.pt/imovel/33083487/',
#    'distance': '2968',
#    'description': 'Este apartamento totalmente equipado e mobilado está disponível a partir de 18-03-2024. Oferecemos preços ajustados para qualquer duração da estadia. As tarifas podem variar nas datas exatas de entrada e saída. O preço deste imóvel começa a €3,000* / mês. Visite o nosso website e coloque as datas pretendidas para saber as condições específicas. *Os preços apresentados: (1) pressupõem a entrada no primeiro dia em que a unidade ficar disponível, (2) aplica-se apenas se o pagamento for feito antecipadamente, o preço pode ser mais elevado se múltiplos pagamentos forem faturados, (3) não inclui impostos e/ou custos de água, gás, eletricidade, internet e TV. Sinta-se em casa com a Blueground, onde quer que decida viver. Vai adorar este apartamento acolhedor Santo António mobilado dois quartos com a sua decoração moderna, cozinha totalmente equipada, e sala de estar confortável living room. Com uma excelente localização, está perto do que Lisbon tem de melhor! (ID  LIS199) Concebido a pensar em si Mobílias deslumbrantes, cozinha totalmente equipada, televisão inteligente ou um altifalante sem fios premium são apenas algumas das comodidades que poderá encontrar dentro deste apartamento dois quartos. Com uma excelente localização na Lisbon, irá adorar tudo o que encontrar fora do apartamento também. Quando estiver pronto para descontrair, ficará feliz por saber que cada quarto Blueground tem colchões de qualidade superior, lençóis de linho de luxo e toalhas aconchegantes. Nós tratamos de tudo para que possa simplesmente chegar e começar a viver. Alojamento  Cama de casal, 140cm/55in  Cama de casal, 140cm/55in Comodidades As comodidades do edifício exclusivas deste apartamento dois quartos incluem:  - Elevador  - Máquina de lavar loiça Chegada e apoio contínuo O apartamento inteiro é todo seu para desfrutar! Será recebido pessoalmente por um membro da equipa Blueground ou receberá instruções de check-in quando se mudar. Durante toda a sua estadia, poderá contactar a nossa equipa de Client Experience através da aplicação Blueground. Partilharemos todos os detalhes após recebermos confirmação da sua estadia. Ubicación ideal Santo António é um bairro dinâmico no centro da cidade de Lisboa. Nesta área de luxo encontramos os marcos mais reconhecíveis da cidade, incluindo a Praça Marquês de Pombal e a Avenida da Liberdade. Os pontos de gastronomia de Santo António incluem vários restaurantes premiados com estrelas Michelin e cozinha internacional diversa, assim como cafés e bares. É neste bairro que encontramos o Museu Nacional de História Natural e Ciência, assim como a Casa-Museu Medeiros e Almeida, uma mansão convertida num elegante museu de arte. O bairro é servido pelas linhas Azul e Amarela do Metro de Lisboa, bem como por várias linhas de autocarros e elétricos. Outros aspetos a salientar As comodidades do edifício podem ter um custo extra. Este apartamento Blueground pode ser reservado por um mínimo de um mês, por um ano ou mais.',
#    'hasVideo': False,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': True,
#    'priceByArea': 32.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Santo António, Lisboa',
#     'title': 'Apartamento na Rua Duque de Palmela'},
#    'hasPlan': True,
#    'has3DTour': True,
#    'has360': False,
#    'hasStaging': False,
#    'labels': [{'name': 'luxuryType', 'text': 'De luxo'}],
#    'highlight': {'groupDescription': 'Destaque'},
#    'topNewDevelopment': False,
#    'topPlus': False},
#   {'propertyCode': '32627960',
#    'thumbnail': 'https://img3.idealista.pt/blur/WEB_LISTING/0/id.pro.pt.image.master/99/5c/31/221592261.jpg',
#    'externalReference': 'LIS-134',
#    'numPhotos': 27,
#    'floor': '3',
#    'price': 3030.0,
#    'propertyType': 'flat',
#    'operation': 'rent',
#    'size': 88.0,
#    'rooms': 2,
#    'bathrooms': 2,
#    'address': 'Rua Vítor Cordon',
#    'province': 'Lisboa',
#    'municipality': 'Santa Maria Maior',
#    'district': 'Chiado',
#    'country': 'pt',
#    'latitude': 38.706729,
#    'longitude': -9.140866,
#    'showAddress': False,
#    'url': 'https://www.idealista.pt/imovel/32627960/',
#    'distance': '4936',
#    'description': 'Este apartamento totalmente equipado e mobilado está disponível a partir de 16-03-2024. Oferecemos preços ajustados para qualquer duração da estadia. As tarifas podem variar nas datas exatas de entrada e saída. O preço deste imóvel começa a €3,030* / mês. Visite o nosso website e coloque as datas pretendidas para saber as condições específicas. *Os preços apresentados: (1) pressupõem a entrada no primeiro dia em que a unidade ficar disponível, (2) aplica-se apenas se o pagamento for feito antecipadamente, o preço pode ser mais elevado se múltiplos pagamentos forem faturados, (3) não inclui impostos e/ou custos de água, gás, eletricidade, internet e TV. Descubra o melhor da Lisbon com este apartamento dois quartos Chiado. Basta aparecer e começar a viver neste apartamento elegante Blueground mobilado com a sua cozinha totalmente equipada, sala de estar sofisticado, e o nosso dedicado apoio no local. (ID  LIS134) Concebido a pensar em si Concebido com inteligência, com acabamentos personalizados, móveis modernos e cozinha totalmente equipada, poderá desfrutar daquela sensação de "estar em casa" com este apartamento Blueground. Quer esteja na sua sala de estar elegante a ver o mais recente e melhor programa de entretenimento na televisão inteligente ou a ouvir os altifalante sem fios premium, ou a ter um descanso bem merecido no colchão de qualidade superior com lençóis de linho de luxo, vai apaixonar-se por tudo o que este apartamento Chiado tem para oferecer.  Alojamento  Cama Queen, 160cm/63in  Cama de casal, 140cm/55in Comodidades As comodidades do edifício exclusivas deste apartamento dois quartos incluem:  - Máquina de lavar loiça  - São permitidos animais Chegada e apoio contínuo O apartamento inteiro é todo seu para desfrutar! Será recebido pessoalmente por um membro da equipa Blueground ou receberá instruções de check-in quando se mudar. Durante toda a sua estadia, poderá contactar a nossa equipa de Client Experience através da aplicação Blueground. Partilharemos todos os detalhes após recebermos confirmação da sua estadia. Ubicación ideal O Chiado é considerado o melhor bairro comercial de Lisboa. Na Rua Garrett, encontra-se a famosa Livraria Bertrand - a mais antiga livraria existente no mundo  bem como inúmeras boutiques de luxo. Esta famosa rua comercial é também um local maravilhoso para jantar, com oferta de cozinha local e internacional. O Chiado é também conhecido pela sua cena teatral, incluindo o Teatro Nacional de São Carlos, de estilo rococó. Este bairro é servido pelas linhas Verde e Azul do Metro de Lisboa, bem como por autocarros e elétricos.  Outros aspetos a salientar As comodidades do edifício podem ter um custo extra. Este apartamento Blueground pode ser reservado por um mínimo de um mês, por um ano ou mais. Os animais de estimação são bem-vindos, embora se apliquem limites de peso e restrições de raça e possam incorrer em taxas. Por favor, tenha em consideração que este é um edifício sem elevador.',
#    'hasVideo': False,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': False,
#    'priceByArea': 34.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Santa Maria Maior, Lisboa',
#     'title': 'Apartamento na Rua Vítor Cordon'},
#    'hasPlan': True,
#    'has3DTour': False,
#    'has360': False,
#    'hasStaging': False,
#    'labels': [{'name': 'luxuryType', 'text': 'De luxo'}],
#    'highlight': {'groupDescription': 'Destaque'},
#    'topNewDevelopment': False,
#    'topPlus': False},
#   {'propertyCode': '32627976',
#    'thumbnail': 'https://img3.idealista.pt/blur/WEB_LISTING/0/id.pro.pt.image.master/7f/14/07/229067771.jpg',
#    'externalReference': 'LIS-136',
#    'numPhotos': 20,
#    'floor': '2',
#    'price': 1980.0,
#    'propertyType': 'flat',
#    'operation': 'rent',
#    'size': 33.0,
#    'rooms': 1,
#    'bathrooms': 1,
#    'address': 'Avenida Miguel Bombarda',
#    'province': 'Lisboa',
#    'municipality': 'Avenidas Novas',
#    'district': 'Campo Pequeno',
#    'country': 'pt',
#    'latitude': 38.7357866,
#    'longitude': -9.1471943,
#    'showAddress': False,
#    'url': 'https://www.idealista.pt/imovel/32627976/',
#    'distance': '1798',
#    'description': 'Este apartamento totalmente equipado e mobilado está disponível a partir de 23-03-2024. Oferecemos preços ajustados para qualquer duração da estadia. As tarifas podem variar nas datas exatas de entrada e saída. O preço deste imóvel começa a €1,870* / mês. Visite o nosso website e coloque as datas pretendidas para saber as condições específicas. *Os preços apresentados: (1) pressupõem a entrada no primeiro dia em que a unidade ficar disponível, (2) aplica-se apenas se o pagamento for feito antecipadamente, o preço pode ser mais elevado se múltiplos pagamentos forem faturados, (3) não inclui impostos e/ou custos de água, gás, eletricidade, internet e TV. Sinta-se em casa com a Blueground, onde quer que decida viver. Vai adorar este apartamento espaçoso Avenidas Novas mobilado T1 com a sua decoração moderna, cozinha totalmente equipada, e sala de estar alegre living room com veranda vista. Com uma excelente localização, está perto do que Lisbon tem de melhor! (ID  LIS136) Concebido a pensar em si Concebido com inteligência, com acabamentos personalizados, móveis modernos e cozinha totalmente equipada, poderá desfrutar daquela sensação de "estar em casa" com este apartamento Blueground. Quer esteja na sua sala de estar sofisticado a ver o mais recente e melhor programa de entretenimento na televisão inteligente ou a ouvir os altifalante sem fios premium, ou a ter um descanso bem merecido no colchão de qualidade superior com lençóis de linho de luxo, vai apaixonar-se por tudo o que este apartamento Avenidas Novas tem para oferecer.  Alojamento  Cama de casal, 140cm/55in Comodidades As comodidades do edifício exclusivas deste apartamento T1 incluem:  - Elevador  - Máquina de lavar loiça  - Estacionamento Chegada e apoio contínuo O apartamento inteiro é todo seu para desfrutar! Será recebido pessoalmente por um membro da equipa Blueground ou receberá instruções de check-in quando se mudar. Durante toda a sua estadia, poderá contactar a nossa equipa de Client Experience através da aplicação Blueground. Partilharemos todos os detalhes após recebermos confirmação da sua estadia. Ubicación ideal Localizada no centro da cidade de Lisboa, Avenidas Novas é um bairro vibrante com uma variedade de atrações culturais, assim como excelentes lojas e áreas de restauração. Uma das principais atrações é o Parque Eduardo VII, um imenso parque com o seu próprio jardim botânico e locais com vistas panorâmicas. Em Avenidas Novas, encontramos o Museu Calouste Gulbenkian, um excelente museu de arte e o centro comercial El Corte Ingles. O bairro é um local maravilhoso onde poderá comer e beber nos vários cafés e restaurantes, e até uma loja de donuts: Crush Donuts. Avenidas Novas é servido pelas linhas Azul e Amarela do Metro de Lisboa, bem como por várias linhas de autocarros e elétricos Outros aspetos a salientar As comodidades do edifício podem ter um custo extra. Este apartamento Blueground pode ser reservado por um mínimo de um mês, por um ano ou mais. Estacionamento é oferecido de acordo com a disponbilidade e pode estar sujeito a um custo adicional.',
#    'hasVideo': False,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': True,
#    'parkingSpace': {'hasParkingSpace': True,
#     'isParkingSpaceIncludedInPrice': False,
#     'parkingSpacePrice': 100.0},
#    'priceByArea': 60.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Avenidas Novas, Lisboa',
#     'title': 'Apartamento na Avenida Miguel Bombarda'},
#    'hasPlan': True,
#    'has3DTour': True,
#    'has360': False,
#    'hasStaging': False,
#    'highlight': {'groupDescription': 'Destaque'},
#    'topNewDevelopment': False,
#    'topPlus': False}],
#  'total': 2946,
#  'totalPages': 59,
#  'actualPage': 1,
#  'itemsPerPage': 50,
#  'numPaginations': 0,
#  'summary': ['Arrendar',
#   'Casas',
#   'Campo Grande, Alvalade',
#   'Todos os preços',
#   'Todos os tamanhos'],
#  'alertName': 'Casas em Campo Grande, Alvalade',
#  'totalAppliedFilters': 0,
#  'lowerRangePosition': 0,
#  'upperRangePosition': 50,
#  'paginable': True}

# %%
# At this point, all the necessary code to extract the data is available, but data extraction is required for
# all the pages of the results. 
# To achieve this, a new function will be created to execute a search for each page number until reaching the last one. For each
# querie it is necessary to save results in a dataframe and subsequently join the dataframes created from each query into a
# final dataframe.

# %%
def extract_data(pagination):
    
    # Dataframe where all the data can be stored
    df_total = pd.DataFrame()

    # This loop will iterate over all the pages in the search results
    for i in range(1, pagination + 1): 
    
        url_page = define_search_url(i)   # Add the pagination to the url
        results = search_api(url_page)   # Get the search results
        df = pd.DataFrame.from_dict(results['elementList'])   # Save the results as a dataframe
        df_total = pd.concat([df_total, df])   # Concat the results to the main dataframe
    
    return df_total

# %%
# check total pages of results because Idealista API has a limitation of 100 search queries/month and each page represents
# one querie.

total_pages = results['totalPages']
total_pages
# Out:
# 59

# %%
df_tot = extract_data(total_pages)

# %%
df_tot
# Out:
#    propertyCode                                          thumbnail  \
# 0      33240191  https://img3.idealista.pt/blur/WEB_LISTING/0/i...
# 1      33240181  https://img3.idealista.pt/blur/WEB_LISTING/0/i...
# 2      32620556  https://img3.idealista.pt/blur/WEB_LISTING/0/i...
# 3      33200256  https://img3.idealista.pt/blur/WEB_LISTING/0/i...
# 4      33240084  https://img3.idealista.pt/blur/WEB_LISTING/0/i...
# ..          ...                                                ...
# 41     33227645                                                NaN
# 42     32994341                                                NaN
# 43     32994662                                                NaN
# 44     33168281                                                NaN
# 45     32407985  https://img3.idealista.pt/blur/WEB_LISTING/0/i...
#
#    externalReference  numPhotos    price propertyType operation     size  \
# 0              59691         50   1000.0         flat      rent    96.00
# 1           W-02V128         39   1750.0         flat      rent   127.00
# 2        EX/002/2023         10   1250.0         flat      rent    60.00
# 3   olivais/001/2024         17   1500.0         flat      rent    85.00
# 4           APA_1952         16   1500.0         flat      rent    72.45
# ..               ...        ...      ...          ...       ...      ...
# 41               NaN          0   4800.0         flat      rent   160.00
# 42               NaN          0   5500.0         flat      rent   280.00
# 43               NaN          0   5500.0         flat      rent   280.00
# 44               NaN          0   1600.0         flat      rent   160.00
# 45               NaN         34  16500.0       chalet      rent  1046.00
#
#     rooms  bathrooms  ... has360 hasStaging topNewDevelopment topPlus floor  \
# 0       4          1  ...  False      False             False   False   NaN
# 1       2          2  ...  False      False             False   False   NaN
# 2       1          1  ...  False      False             False   False     1
# 3       1          1  ...   True      False             False   False     3
# 4       2          1  ...  False      False             False   False     3
# ..    ...        ...  ...    ...        ...               ...     ...   ...
# 41      3          2  ...  False      False             False   False     6
# 42      4          3  ...  False      False             False   False     5
# 43      4          3  ...  False      False             False   False     5
# 44      4          3  ...  False      False             False   False    12
# 45     11          4  ...  False      False             False   False   NaN
#
#                            highlight  \
# 0                                NaN
# 1                                NaN
# 2   {'groupDescription': 'Destaque'}
# 3   {'groupDescription': 'Destaque'}
# 4                                NaN
# ..                               ...
# 41                               NaN
# 42                               NaN
# 43                               NaN
# 44                               NaN
# 45                               NaN
#
#                                          parkingSpace  neighborhood  \
# 0                                                 NaN           NaN
# 1                                                 NaN           NaN
# 2                                                 NaN           NaN
# 3   {'hasParkingSpace': True, 'isParkingSpaceInclu...           NaN
# 4                                                 NaN           NaN
# ..                                                ...           ...
# 41  {'hasParkingSpace': True, 'isParkingSpaceInclu...           NaN
# 42  {'hasParkingSpace': True, 'isParkingSpaceInclu...           NaN
# 43  {'hasParkingSpace': True, 'isParkingSpaceInclu...           NaN
# 44  {'hasParkingSpace': True, 'isParkingSpaceInclu...           NaN
# 45  {'hasParkingSpace': True, 'isParkingSpaceInclu...           NaN
#
#                                          labels newDevelopmentFinished
# 0                                           NaN                    NaN
# 1                                           NaN                    NaN
# 2                                           NaN                    NaN
# 3                                           NaN                    NaN
# 4                                           NaN                    NaN
# ..                                          ...                    ...
# 41  [{'name': 'luxuryType', 'text': 'De luxo'}]                    NaN
# 42  [{'name': 'luxuryType', 'text': 'De luxo'}]                    NaN
# 43  [{'name': 'luxuryType', 'text': 'De luxo'}]                    NaN
# 44                                          NaN                    NaN
# 45                                          NaN                    NaN
#
# [2946 rows x 40 columns]

# %%
# Once all the data is collected, it just needs to be saved as a CSV file. 
# The following function has been created for that purpose:

file_path = 'idealista.csv'

def df_to_csv(df):
    '''
    This function will take a given dataframe and save it as a csv file
    '''
    df = df.reset_index()   # Reset the index in order to organise the records
    df.to_csv(file_path, index=False)   # Save it into a csv

# %%
# Executing the function to obtain a CSV file with all the extracted data.
df_to_csv(df_tot)

# %%
# Idealista API has a limitation of 100 search queries/month, so this should be taken into 
# consideration when performing the search queries
